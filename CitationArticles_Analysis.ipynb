# %% [markdown]
# <a href="https://colab.research.google.com/github/DentalInformatics/DentalInformatics/blob/main/CitationArticles_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mounting the drive for collecting data from csv files 
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls "/content/drive/My Drive/Latest_JSON_Files/"
# Out:
# Article0.json    Article33.json  Article70.json
# Article100.json  Article34.json  Article71.json
# Article101.json  Article35.json  Article72.json
# Article102.json  Article36.json  Article73.json
# Article103.json  Article37.json  Article74.json
# Article104.json  Article38.json  Article75.json
# Article105.json  Article39.json  Article76.json
# Article106.json  Article3.json   Article77.json
# Article107.json  Article40.json  Article78.json
# Article108.json  Article41.json  Article79.json
# Article109.json  Article42.json  Article7.json
# Article10.json   Article43.json  Article80.json
# Article110.json  Article44.json  Article81.json
# Article111.json  Article45.json  Article82.json
# Article112.json  Article46.json  Article83.json
# Article113.json  Article47.json  Article84.json
# Article114.json  Article48.json  Article85.json
# Article11.json   Article49.json  Article86.json
# Article12.json   Article4.json   Article87.json
# Article13.json   Article50.json  Article88.json
# Article14.json   Article51.json  Article89.json
# Article15.json   Article52.json  Article8.json
# Article16.json   Article53.json  Article90.json
# Article17.json   Article54.json  Article91.json
# Article18.json   Article55.json  Article92.json
# Article19.json   Article56.json  Article93.json
# Article1.json    Article57.json  Article94.json
# Article20.json   Article58.json  Article95.json
# Article21.json   Article59.json  Article96.json
# Article22.json   Article5.json   Article97.json
# Article23.json   Article60.json  Article98.json
# Article24.json   Article61.json  Article99.json
# Article25.json   Article62.json  Article9.json
# Article26.json   Article63.json  Article_information_Final.csv
# Article27.json   Article64.json  Article_information_jan26.csv
# Article28.json   Article65.json  author_info_withdoi.csv
# Article29.json   Article66.json  author_names.csv
# Article2.json    Article67.json  Latest_Article_info_jan26_pubmed.csv
# Article30.json   Article68.json  Latest_files_Jan26_pubmed/
# Article31.json   Article69.json  Reference_articles.csv
# Article32.json   Article6.json   table4.csv

# %%
#collection of citation information from all the json files and appending it to a dataframe and generating csv file.
import json
import pandas as pd
import numpy as np
from pandas import DataFrame
article_id = []
citingpaperId = []
citingdoi = []
citingtitle = []
citingvenue = []
citingyear = []
citingintent = []
citinginfluential = []
authornamelist= []
authoridlist = []
authorurllist = []
for i in range(115):
  f = open('/content/drive/My Drive/Latest_JSON_Files/Article' + str(i) + '.json')
  data = json.load(f)
  print("****** i",i)
  article_data = data['doi']
  for value in data['citations']:
    paperId = value['paperId']
    doi = value['doi']
    title = value['title']
    venue = value['venue']
    year = value['year']
    intent = value['intent']
    isInfluential = value['isInfluential']
    for i in value['authors']:
     citingpaperId.append(paperId)
     article_id.append(article_data)
     citingdoi.append(doi)
     citingtitle.append(title)
     citingvenue.append(venue)
     citingyear.append(year)
     citingintent.append(intent)
     citinginfluential.append(isInfluential) 
     authorname = i['name']
     authornamelist.append(authorname)
     authorid = i['authorId']
     authoridlist.append(authorid)
    #  authorurl= i['url']
    #  authorurllist.append(authorurl) 
a = {'article_id': article_id,'authorid': authoridlist,'authorname':authornamelist,'authorurl': authorurllist, 'paperId' : citingpaperId ,'doi' : citingdoi ,'title' : citingtitle ,
     'citing_venue' :citingvenue, 'year': citingyear,
     'intent' : citingintent,'isInfluential' : citinginfluential}
df = pd.DataFrame.from_dict(a, orient='index')
df1 = df.transpose()
df1['intent'] = df1['intent'].apply(lambda x : ' '.join(map(str, x)))
df1.to_csv('table3.csv', columns = a)
df1
# Out:
# ****** i 0
# ****** i 1
# ****** i 2
# ****** i 3
# ****** i 4
# ****** i 5
# ****** i 6
# ****** i 7
# ****** i 8
# ****** i 9
# ****** i 10
# ****** i 11
# ****** i 12
# ****** i 13
# ****** i 14
# ****** i 15
# ****** i 16
# ****** i 17
# ****** i 18
# ****** i 19
# ****** i 20
# ****** i 21
# ****** i 22
# ****** i 23
# ****** i 24
# ****** i 25
# ****** i 26
# ****** i 27
# ****** i 28
# ****** i 29
# ****** i 30
# ****** i 31
# ****** i 32
# ****** i 33
# ****** i 34
# ****** i 35
# ****** i 36
# ****** i 37
# ****** i 38
# ****** i 39
# ****** i 40
# ****** i 41
# ****** i 42
# ****** i 43
# ****** i 44
# ****** i 45
# ****** i 46
# ****** i 47
# ****** i 48
# ****** i 49
# ****** i 50
# ****** i 51
# ****** i 52
# ****** i 53
# ****** i 54
# ****** i 55
# ****** i 56
# ****** i 57
# ****** i 58
# ****** i 59
# ****** i 60
# ****** i 61
# ****** i 62
# ****** i 63
# ****** i 64
# ****** i 65
# ****** i 66
# ****** i 67
# ****** i 68
# ****** i 69
# ****** i 70
# ****** i 71
# ****** i 72
# ****** i 73
# ****** i 74
# ****** i 75
# ****** i 76
# ****** i 77
# ****** i 78
# ****** i 79
# ****** i 80
# ****** i 81
# ****** i 82
# ****** i 83
# ****** i 84
# ****** i 85
# ****** i 86
# ****** i 87
# ****** i 88
# ****** i 89
# ****** i 90
# ****** i 91
# ****** i 92
# ****** i 93
# ****** i 94
# ****** i 95
# ****** i 96
# ****** i 97
# ****** i 98
# ****** i 99
# ****** i 100
# ****** i 101
# ****** i 102
# ****** i 103
# ****** i 104
# ****** i 105
# ****** i 106
# ****** i 107
# ****** i 108
# ****** i 109
# ****** i 110
# ****** i 111
# ****** i 112
# ****** i 113
# ****** i 114
#                          article_id    authorid           authorname  \
# 0         10.5455/aim.2012.20.47-55  2162871696     Ballester Benoit
# 1         10.5455/aim.2012.20.47-55  2162871951      Bukiet Frédéric
# 2         10.5455/aim.2012.20.47-55  2162871920  Dufour Jean-Charles
# 3         10.5455/aim.2012.20.47-55  2163317317   A. S. A. AL-Ghamdi
# 4         10.5455/aim.2012.20.47-55  2144746353        Mahmoud Ragab
# ...                             ...         ...                  ...
# 8926  10.3233/978-1-61499-645-3-230     3218479             K. Zvára
# 8927  10.3233/978-1-61499-645-3-230     1983950         M. Tomecková
# 8928  10.3233/978-1-61499-645-3-230     1746497           J. Peleska
# 8929  10.3233/978-1-61499-645-3-230     1740821            V. Svátek
# 8930  10.3233/978-1-61499-645-3-230    32246566           J. Zvárová
#
#      authorurl                                   paperId  \
# 0         None  6a96aa231f1bb1dcada2c093ea91df1982c5400e
# 1         None  6a96aa231f1bb1dcada2c093ea91df1982c5400e
# 2         None  6a96aa231f1bb1dcada2c093ea91df1982c5400e
# 3         None  d4d90a1d78a6411e92c298fc8a833ab84c00a9df
# 4         None  d4d90a1d78a6411e92c298fc8a833ab84c00a9df
# ...        ...                                       ...
# 8926      None  18b86d657c68b8e05956f9b32e22c0188ed08c0e
# 8927      None  18b86d657c68b8e05956f9b32e22c0188ed08c0e
# 8928      None  18b86d657c68b8e05956f9b32e22c0188ed08c0e
# 8929      None  18b86d657c68b8e05956f9b32e22c0188ed08c0e
# 8930      None  18b86d657c68b8e05956f9b32e22c0188ed08c0e
#
#                              doi  \
# 0     10.1186/s12903-022-02163-9
# 1     10.1186/s12903-022-02163-9
# 2     10.1186/s12903-022-02163-9
# 3           10.1155/2022/3500552
# 4           10.1155/2022/3500552
# ...                          ...
# 8926        10.3414/ME16-01-0083
# 8927        10.3414/ME16-01-0083
# 8928        10.3414/ME16-01-0083
# 8929        10.3414/ME16-01-0083
# 8930        10.3414/ME16-01-0083
#
#                                                   title  \
# 0     Current state of dental informatics in the fie...
# 1     Current state of dental informatics in the fie...
# 2     Current state of dental informatics in the fie...
# 3     Detection of Dental Diseases through X-Ray Ima...
# 4     Detection of Dental Diseases through X-Ray Ima...
# ...                                                 ...
# 8926  Tool-supported Interactive Correction and Sema...
# 8927  Tool-supported Interactive Correction and Sema...
# 8928  Tool-supported Interactive Correction and Sema...
# 8929  Tool-supported Interactive Correction and Sema...
# 8930  Tool-supported Interactive Correction and Sema...
#
#                                      citing_venue  year      intent  \
# 0                                 BMC oral health  2022
# 1                                 BMC oral health  2022
# 2                                 BMC oral health  2022
# 3     Computational intelligence and neuroscience  2022  background
# 4     Computational intelligence and neuroscience  2022  background
# ...                                           ...   ...         ...
# 8926           Methods of information in medicine  2017
# 8927           Methods of information in medicine  2017
# 8928           Methods of information in medicine  2017
# 8929           Methods of information in medicine  2017
# 8930           Methods of information in medicine  2017
#
#      isInfluential
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ...            ...
# 8926         False
# 8927         False
# 8928         False
# 8929         False
# 8930         False
#
# [8931 rows x 11 columns]

# %%
df = pd.read_csv("table3.csv",encoding = "ISO-8859-1")
# df['Reference_paper_venue'] = df['Reference_paper_venue'].str.lower()
df1 = df[['citing_venue','article_id']]
df1.replace('', np.nan, inplace=True)
df1.drop_duplicates()
df2=df1.groupby('citing_venue')['article_id'].nunique().reset_index(name="count")
df2
df2.nlargest(5, ['count'])[["citing_venue","count"]]
df3 = df2.sort_values('count',ascending=False)
df3["Rank"] = df3["count"].rank(ascending=False)
df4 = df3.dropna(subset=['Rank'])
header = ["citing_venue", "Rank"]
df4.to_csv('citing_venue.csv', columns = header)
plotgraph = pd.read_csv("citing_venue.csv")
plotgraph = df2.nlargest(10, ['count'])[["citing_venue","count"]]
rank=pd.read_csv("citing_venue.csv")
top10rank = rank.head(10)
top10rank
# plotgraph['Rank'] = top10rank['Rank'].values
plotgraph.to_csv("citing_venue_f.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
#Plotting a graph for top 10 authors with the maximum number of articles published.
import pandas as pd
import matplotlib.pyplot as plt
plotgraph= pd.read_csv("CitingVenue_fullnames.csv",encoding = "ISO-8859-1")
plotgraph.set_index("citing_venue",drop=True,inplace=True)
ax=plotgraph.plot.barh(color = 'orange')
ax.invert_yaxis()
plt.title("Top 10 citation Journals",fontsize=20)
plt.xlabel("count",fontsize=14)
plt.ylabel("Journals",fontsize=14)
venue=plotgraph['count']
# plotgraph= df.nlargest(10, ['count'])[["Reference_paper_venue","count"]]
# plotgraph
ax.legend().set_visible(False)
for i, v in enumerate(venue):
    ax.text(v, i, str(v),
            color = 'black', fontweight = 'bold')
# plt.savefig('ref_Analysis_graph.png',bbox_inches='tight',dpi=400)
plt.savefig('Citation_Analysis_graph.png',bbox_inches='tight',dpi=400)
plt.show()
