# %% [markdown]
# <a href="https://colab.research.google.com/github/DentalInformatics/DentalInformatics/blob/main/Visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Plotting a graph for top 10 Insititutions
import pandas as pd
import matplotlib.pyplot as plt
plotgraph= pd.read_csv("top10Institutions_Vis.csv",encoding = "ISO-8859-1")
plotgraph.set_index("Insitutions",drop=True,inplace=True)
ax=plotgraph.plot.barh(color = 'Olive')
ax.invert_yaxis()
venue=plotgraph['Count']
# plt.title("Top 10 Reference Articles Venues",fontsize=20)
plt.xlabel("Count",fontsize=14)
plt.ylabel("Insitutions",fontsize=14)
ax.legend().set_visible(False)
for i, v in enumerate(venue):
    ax.text(v, i, str(v),
            color = 'black', fontweight = 'bold')
plt.savefig('Top10Insitituions_graph.png',bbox_inches='tight',dpi=400)
plt.show()
# plotgraph= df.nlargest(10, ['count'])[["Reference_paper_venue","count"]]
# plotgraph

# %%
#No of Articles vs Authors in Article
import matplotlib.pyplot as plt
data = pd.read_csv("AuthorsVsNoOfArticles.csv")
x=data["No of Articles"]
y=data["Authors in Article"]
print(type(x))
plt.plot(x, y)
  
# naming the x axis
plt.xlabel('No of Articles')
# naming the y axis
plt.ylabel('Authors in Article')
  
# giving a title to my graph
# plt.title('Articles Vs Number of Authors')
  
# function to show the plot
plt.show()
# Out:
# <class 'pandas.core.series.Series'>

# %%
#Plotting a graph for top 10 venues
import pandas as pd
import matplotlib.pyplot as plt
plotgraph= pd.read_csv("Top10Venues.csv",encoding = "ISO-8859-1")
plotgraph.set_index("Journal",drop=True,inplace=True)
ax=plotgraph.plot.barh(color = 'pink')
ax.invert_yaxis()
venue=plotgraph['Count']
# plt.title("Top 10 Reference Articles Venues",fontsize=20)
plt.xlabel("Count",fontsize=14)
plt.ylabel("venue",fontsize=14)
ax.legend().set_visible(False)
for i, v in enumerate(venue):
    ax.text(v, i, str(v),
            color = 'black', fontweight = 'bold')
plt.savefig('Top10Venues_graph.png',bbox_inches='tight',dpi=400)
plt.show()
# plotgraph= df.nlargest(10, ['count'])[["Reference_paper_venue","count"]]
# plotgraph
